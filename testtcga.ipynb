# %% [markdown]
# First, import the file.

# %%
import numpy as np
import pandas as pd
tcga = pd.read_csv("TCGA_all_tidy_with_metadata.csv")
# Out:
# /var/folders/mx/gxf97ng570s7yk1k1q90flr40000gn/T/ipykernel_7645/1276675347.py:3: DtypeWarning: Columns (20536,20537,20538,20548,20549,20550,20558,20559,20560,20561,20562,20563,20564,20565,20566,20567,20569) have mixed types. Specify dtype option on import or set low_memory=False.
#   tcga = pd.read_csv("TCGA_all_tidy_with_metadata.csv")

# %% [markdown]
# Next, chop off the first two columns.

# %%
tcga_new = tcga.iloc[:, 2:]

# %%
tcga.head()
# Out:
#    Unnamed: 0  ARHGEF10L   HIF3A  RNF17    RNF10    RNF11    RNF13  GTF2IP1  \
# 0           1     6.2537  4.7431    0.0  12.3405  10.2326   9.9114  12.6294
# 1           2     8.6468  4.4576    0.0  12.1763  10.2696   9.9354  12.6974
# 2           3     8.0773  5.2181    0.0  13.4269  10.4399  10.4480  12.6752
# 3           4     8.5349  2.4357    0.0  12.3032  10.3281  10.4491  12.6055
# 4           5     8.9196  5.8492    0.0  12.4274  10.4852  11.0181  13.1200
#
#      REM1   MTVR2  ...  Subtype_miRNA                          Subtype_mRNA  \
# 0  4.8144  0.7471  ...        miRNA_1  steroid-phenotype-high+proliferation
# 1  4.2702  0.5323  ...        miRNA_4                steroid-phenotype-high
# 2  1.8429  0.0000  ...        miRNA_6                 steroid-phenotype-low
# 3  5.0432  0.0000  ...        miRNA_5                 steroid-phenotype-low
# 4  2.4917  0.0000  ...        miRNA_6                 steroid-phenotype-low
#
# ...

# %% [markdown]
# Now, we have our clean file.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(ncols=1, figsize=(30,5))
sns.scatterplot(x="ASS1", y="SLC7A5", data=tcga)
# Out:
# <Axes: xlabel='ASS1', ylabel='SLC7A5'>
